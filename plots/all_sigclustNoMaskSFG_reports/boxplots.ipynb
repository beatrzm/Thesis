# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from scipy import stats
import os

# %% [markdown]
# Import data

# %%
numbers_controls = range(19, 52)

# Dictionary to store DataFrames
dataframes_mid = {}

for i in numbers_controls:
    sub_control = f"sub-control{i:03d}"
    filename = f"featqueryreport_{sub_control}_ses-midcycle_sigclustNoMaskSFG.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\plots\\all_sigclustNoMaskSFG_reports", filename)
    if os.path.exists(filepath):
        dataframes_mid[f"control{i}_ses-midcycle"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_mid[f'control{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_mid))

# Dictionary to store DataFrames
dataframes_premens = {}

for i in numbers_controls:
    sub_control = f"sub-control{i:03d}"
    filename = f"featqueryreport_{sub_control}_ses-premenstrual_sigclustNoMaskSFG.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\plots\\all_sigclustNoMaskSFG_reports", filename)
    if os.path.exists(filepath):
        dataframes_premens[f"control{i}_ses-premenstrual"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_premens[f'control{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_premens))
# Out:
# 15
# 15

# %%
numbers_patients = range(1, 53)

dataframes_int = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-interictal_sigclustNoMaskSFG.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\plots\\all_sigclustNoMaskSFG_reports", filename)
    if os.path.exists(filepath):
        dataframes_int[f"patient{i}_ses-interictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_int[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_int))

# Dictionary to store DataFrames
dataframes_preictal = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-preictal_sigclustNoMaskSFG.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\plots\\all_sigclustNoMaskSFG_reports", filename)
    if os.path.exists(filepath):
        dataframes_preictal[f"patient{i}_ses-preictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_preictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_preictal))

# Dictionary to store DataFrames
dataframes_ictal = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-ictal_sigclustNoMaskSFG.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\plots\\all_sigclustNoMaskSFG_reports", filename)
    if os.path.exists(filepath):
        dataframes_ictal[f"patient{i}_ses-ictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_ictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_ictal))

# Dictionary to store DataFrames
dataframes_postictal = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-postictal_sigclustNoMaskSFG.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\plots\\all_sigclustNoMaskSFG_reports", filename)
    if os.path.exists(filepath):
        dataframes_postictal[f"patient{i}_ses-postictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_postictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_postictal))
# Out:
# 13
# 12
# 14
# 12

# %% [markdown]
# First plots (COPE8) and functions

# %%
def extract_values(dataframes, iloc_position):
    extracted_values = []
    for key in dataframes:
        extracted_values.append(dataframes[key].iloc[iloc_position[0], iloc_position[1]])
    return extracted_values

midcycle = extract_values(dataframes_mid, (0, 5))
premenstrual = extract_values(dataframes_premens, (0, 5))
interictal = extract_values(dataframes_int, (0, 5))
preictal = extract_values(dataframes_preictal, (0, 5))
ictal = extract_values(dataframes_ictal, (0, 5))
postictal = extract_values(dataframes_postictal, (0, 5))

# %%
# qq plot of each phase

fig, axs = plt.subplots(2, 3, figsize=(8, 4))
fig.suptitle("QQ plots of sigclustNoMaskSFG % mean signal change for each phase in COPE8")

stats.probplot(midcycle, dist="norm", plot=axs[0, 0])
axs[0, 0].set_title("Midcycle", fontsize=8)

stats.probplot(premenstrual, dist="norm", plot=axs[0, 1])
axs[0, 1].set_title("Premenstrual", fontsize=8)

stats.probplot(interictal, dist="norm", plot=axs[0, 2])
axs[0, 2].set_title("Interictal", fontsize=8)

stats.probplot(preictal, dist="norm", plot=axs[1, 0])
axs[1, 0].set_title("Preictal", fontsize=8)

stats.probplot(ictal, dist="norm", plot=axs[1, 1])
axs[1, 1].set_title("Ictal", fontsize=8)

stats.probplot(postictal, dist="norm", plot=axs[1, 2])
axs[1, 2].set_title("Postictal", fontsize=8)

plt.tight_layout()
plt.show()

# %%
## sahpiro-wilk test for normality

midcycle_shapiro = stats.shapiro(midcycle)
premenstrual_shapiro = stats.shapiro(premenstrual)
interictal_shapiro = stats.shapiro(interictal)
preictal_shapiro = stats.shapiro(preictal)
ictal_shapiro = stats.shapiro(ictal)
postictal_shapiro = stats.shapiro(postictal)

print(f"Midcycle: {midcycle_shapiro}")
print(f"Premenstrual: {premenstrual_shapiro}")
print(f"Interictal: {interictal_shapiro}")
print(f"Preictal: {preictal_shapiro}")
print(f"Ictal: {ictal_shapiro}")
print(f"Postictal: {postictal_shapiro}")
# Out:
# Midcycle: ShapiroResult(statistic=0.9440762116646821, pvalue=0.43639471448873596)
# Premenstrual: ShapiroResult(statistic=0.9623921123161239, pvalue=0.7338879167346098)
# Interictal: ShapiroResult(statistic=0.9419516299545646, pvalue=0.4826667445548051)
# Preictal: ShapiroResult(statistic=0.8896131474237214, pvalue=0.11649438745046731)
# Ictal: ShapiroResult(statistic=0.8946232217280127, pvalue=0.09426167947311383)
# Postictal: ShapiroResult(statistic=0.8957544491711155, pvalue=0.13981239644939253)

# %%
# test for significance

midvsinter8 = stats.ttest_ind(midcycle, interictal)
premensvspreict8 = stats.ttest_ind(premenstrual, preictal)
premensvsict8 = stats.ttest_ind(premenstrual, ictal)
premensvspostict8 = stats.ttest_ind(premenstrual, postictal)
midvspremens8 = stats.ttest_rel(midcycle, premenstrual)

print("Midcycle vs Interictal unpaired t-test for COPE8: ",midvsinter8)
print("Premenstrual vs Preictal unpaired t-test for COPE8: ",premensvspreict8)
print("Premenstrual vs Ictal unpaired t-test for COPE8: ",premensvsict8)
print("Premenstrual vs Postictal unpaired t-test for COPE8: ",premensvspostict8)
print("Midcycle vs Premenstrual paired t-test for COPE8: ",midvspremens8)
# Out:
# Midcycle vs Interictal unpaired t-test for COPE8:  TtestResult(statistic=-0.8454968429547303, pvalue=0.4055475309974982, df=26.0)
# Premenstrual vs Preictal unpaired t-test for COPE8:  TtestResult(statistic=-6.3892611239868335, pvalue=1.0902873973644741e-06, df=25.0)
# Premenstrual vs Ictal unpaired t-test for COPE8:  TtestResult(statistic=-3.4841152181419273, pvalue=0.001701546047328309, df=27.0)
# Premenstrual vs Postictal unpaired t-test for COPE8:  TtestResult(statistic=-0.9619805382153588, pvalue=0.3452723184964205, df=25.0)
# Midcycle vs Premenstrual paired t-test for COPE8:  TtestResult(statistic=1.8874642674379272, pvalue=0.080004562658365, df=14)

# %%
def plot_boxplot_with_significance(data, ROIname, COPEname, significance_tests):
    """
    Plot a boxplot with significance markers.

    Args:
        data (list): List of data arrays for boxplot.
        ROIname (string): Name of the ROI.
        COPEname (string): Name of the COPE.
        significance_tests (list of tuples): List of tuples containing significance test results.

    Returns:
        None
    """
    positions = [1, 2, 3, 4, 5, 6]
    phase_names = ['Midcycle', 'Premenstrual', 'Interictal', 'Preictal', 'Ictal', 'Postictal']

    # Create the boxplot with equal width
    boxprops_green = dict(color="lightgreen", facecolor="lightgreen", linewidth=2)
    boxprops_red = dict(color="lightcoral", facecolor="lightcoral", linewidth=2)
    medianprops_black = dict(color="black", linewidth=2)

    plt.boxplot(data[:-2], positions=positions[:-2], patch_artist=True, boxprops=boxprops_green, medianprops=medianprops_black, widths=0.5)
    plt.boxplot(data[-4:], positions=positions[-4:], patch_artist=True, boxprops=boxprops_red, medianprops=medianprops_black, widths=0.5)

    # Set x-axis labels
    plt.xticks(positions, phase_names, fontsize=8)

    # Add significance markers
    max_value = max(max(data[0]), max(data[1]), max(data[2]), max(data[3]), max(data[4]), max(data[5]))
    offset = 0.02

    
    #for i, test_result in enumerate(significance_tests):
    #    if test_result[1].pvalue < 0.05:
    #        plt.hlines(max_value + offset, positions[test_result[0][0]], positions[test_result[0][1]], color='black', linewidth=2)
    #        plt.text((positions[test_result[0][0]] + positions[test_result[0][1]]) * 0.5, max_value + (i+1) * offset, '*', ha='center', va='bottom', fontsize=16)

    #plt.ylim(-2.5,2.5)

    plt.ylabel('Mean % signal change')
    plt.title(f'Mean % signal change for {COPEname} in the {ROIname} (stats map)')
    plt.show()

# %%
data = [midcycle, premenstrual, interictal, preictal, ictal, postictal]
significance_tests = [((0, 2), midvsinter8), ((1, 3), premensvspreict8), ((1, 4), premensvsict8), ((1, 5), premensvspostict8), ((0, 1), midvspremens8)] # first position in the tuple is the phases being compared (so the function knows where to draw the line), second position is the t-test result

plot_boxplot_with_significance(data, 'sigclustNoMaskSFG', "COPE 8 (H>N)", significance_tests)

# %%
# one sample t test for each phase with H0 = 0

midcycle_one_sample = stats.ttest_1samp(midcycle, 0)
premenstrual_one_sample = stats.ttest_1samp(premenstrual, 0)
interictal_one_sample = stats.ttest_1samp(interictal, 0)
preictal_one_sample = stats.ttest_1samp(preictal, 0)
ictal_one_sample = stats.ttest_1samp(ictal, 0)
postictal_one_sample = stats.ttest_1samp(postictal, 0)

print(f"Midcycle COPE8 one sample t-test with H0=0: {midcycle_one_sample}")
print(f"Premenstrual COPE8 one sample t-test with H0=0: {premenstrual_one_sample}")
print(f"Interictal COPE8 one sample t-test with H0=0: {interictal_one_sample}")
print(f"Preictal COPE8 one sample t-test with H0=0: {preictal_one_sample}")
print(f"Ictal COPE8 one sample t-test with H0=0: {ictal_one_sample}")
print(f"Postictal COPE8 one sample t-test with H0=0: {postictal_one_sample}")
# Out:
# Midcycle COPE8 one sample t-test with H0=0: TtestResult(statistic=-0.15911863005278623, pvalue=0.8758480737993564, df=14)
# Premenstrual COPE8 one sample t-test with H0=0: TtestResult(statistic=-4.7834963245446005, pvalue=0.0002914707505545141, df=14)
# Interictal COPE8 one sample t-test with H0=0: TtestResult(statistic=1.0323692910419222, pvalue=0.32225767424982055, df=12)
# Preictal COPE8 one sample t-test with H0=0: TtestResult(statistic=4.671117514228999, pvalue=0.0006813050422087308, df=11)
# Ictal COPE8 one sample t-test with H0=0: TtestResult(statistic=1.0037027020941796, pvalue=0.3338393388006222, df=13)
# Postictal COPE8 one sample t-test with H0=0: TtestResult(statistic=-1.3261404062977629, pvalue=0.21167010315143256, df=11)

# %%
midcycle_thr = extract_values(dataframes_mid, (3, 5))
premenstrual_thr = extract_values(dataframes_premens, (3, 5))
interictal_thr = extract_values(dataframes_int, (3, 5))
preictal_thr = extract_values(dataframes_preictal, (3, 5))
ictal_thr = extract_values(dataframes_ictal, (3, 5))
postictal_thr = extract_values(dataframes_postictal, (3, 5))

# %%
def plot_boxplot(data, ROIname, COPEname):
    """
    Plot a boxplot with significance markers.

    Args:
        data (list): List of data arrays for boxplot.
        ROIname (string): Name of the ROI.

    Returns:
        None
    """
    positions = [1, 2, 3, 4, 5, 6]
    phase_names = ['Midcycle', 'Premenstrual', 'Interictal', 'Preictal', 'Ictal', 'Postictal']

    # Create the boxplot with equal width
    boxprops_green = dict(color="lightgreen", facecolor="lightgreen", linewidth=2)
    boxprops_red = dict(color="lightcoral", facecolor="lightcoral", linewidth=2)
    medianprops_black = dict(color="black", linewidth=2)

    plt.boxplot(data[:-2], positions=positions[:-2], patch_artist=True, boxprops=boxprops_green, medianprops=medianprops_black, widths=0.5)
    plt.boxplot(data[-4:], positions=positions[-4:], patch_artist=True, boxprops=boxprops_red, medianprops=medianprops_black, widths=0.5)

    # Set x-axis labels
    plt.xticks(positions, phase_names, fontsize=8)

    plt.ylabel('Mean % signal change')
    plt.title(f'Mean % signal change for {COPEname} in the {ROIname} (thresh_ztat map)')
    plt.show()

# %%
data = [midcycle_thr, premenstrual_thr, interictal_thr, preictal_thr, ictal_thr, postictal_thr]

plot_boxplot(data, 'sigclustNoMaskSFG', "COPE 8 (H>N)")

# %% [markdown]
# COPE9

# %%
midcycle9 = extract_values(dataframes_mid, (1, 5))
premenstrual9 = extract_values(dataframes_premens, (1, 5))
interictal9 = extract_values(dataframes_int, (1, 5))
preictal9 = extract_values(dataframes_preictal, (1, 5))
ictal9 = extract_values(dataframes_ictal, (1, 5))
postictal9 = extract_values(dataframes_postictal, (1, 5))

# %%
# qq plot of each phase

fig, axs = plt.subplots(2, 3, figsize=(8, 4))
fig.suptitle("QQ plots of sigclustNoMaskSFG % mean signal change for each phase in COPE 9")

stats.probplot(midcycle9, dist="norm", plot=axs[0, 0])
axs[0, 0].set_title("Midcycle", fontsize=8)
stats.probplot(premenstrual9, dist="norm", plot=axs[0, 1])
axs[0, 1].set_title("Premenstrual", fontsize=8)
stats.probplot(interictal9, dist="norm", plot=axs[0, 2])
axs[0, 2].set_title("Interictal", fontsize=8)
stats.probplot(preictal9, dist="norm", plot=axs[1, 0])
axs[1, 0].set_title("Preictal", fontsize=8)
stats.probplot(ictal9, dist="norm", plot=axs[1, 1])
axs[1, 1].set_title("Ictal", fontsize=8)
stats.probplot(postictal9, dist="norm", plot=axs[1, 2])
axs[1, 2].set_title("Postictal", fontsize=8)

plt.tight_layout()
plt.show()

# %%
# shapiro-wilk test for normality

midcycle_shapiro9 = stats.shapiro(midcycle9)
premenstrual_shapiro9 = stats.shapiro(premenstrual9)
interictal_shapiro9 = stats.shapiro(interictal9)
preictal_shapiro9 = stats.shapiro(preictal9)
ictal_shapiro9 = stats.shapiro(ictal9)
postictal_shapiro9 = stats.shapiro(postictal9)

print(f"Midcycle: {midcycle_shapiro9}")
print(f"Premenstrual: {premenstrual_shapiro9}")
print(f"Interictal: {interictal_shapiro9}")
print(f"Preictal: {preictal_shapiro9}")
print(f"Ictal: {ictal_shapiro9}")
print(f"Postictal: {postictal_shapiro9}")
# Out:
# Midcycle: ShapiroResult(statistic=0.9289350346539808, pvalue=0.26304087659473474)
# Premenstrual: ShapiroResult(statistic=0.9818087017392859, pvalue=0.9803488841906272)
# Interictal: ShapiroResult(statistic=0.9235102273836459, pvalue=0.279641762470361)
# Preictal: ShapiroResult(statistic=0.9456786500394475, pvalue=0.5749126809641336)
# Ictal: ShapiroResult(statistic=0.8871334336209787, pvalue=0.07350974040635266)
# Postictal: ShapiroResult(statistic=0.9770833207979244, pvalue=0.9692931537990599)

# %%
midvsinter9 = stats.ttest_ind(midcycle9, interictal9)
premensvspreict9 = stats.ttest_ind(premenstrual9, preictal9)
premensvsict9 = stats.ttest_ind(premenstrual9, ictal9)
premensvspostict9 = stats.ttest_ind(premenstrual9, postictal9)
midvspremens9 = stats.ttest_rel(midcycle9, premenstrual9)

print("Midcycle vs Interictal unpaired t-test for COPE9: ",midvsinter9)
print("Premenstrual vs Preictal unpaired t-test for COPE9: ",premensvspreict9)
print("Premenstrual vs Ictal unpaired t-test for COPE9: ",premensvsict9)
print("Premenstrual vs Postictal unpaired t-test for COPE9: ",premensvspostict9)
print("Midcycle vs Premenstrual paired t-test for COPE9: ",midvspremens9)
# Out:
# Midcycle vs Interictal unpaired t-test for COPE9:  TtestResult(statistic=-1.3166958739560353, pvalue=0.19942941293955907, df=26.0)
# Premenstrual vs Preictal unpaired t-test for COPE9:  TtestResult(statistic=-2.241144941598301, pvalue=0.03413833615439795, df=25.0)
# Premenstrual vs Ictal unpaired t-test for COPE9:  TtestResult(statistic=-1.6619020327211782, pvalue=0.10810118872482358, df=27.0)
# Premenstrual vs Postictal unpaired t-test for COPE9:  TtestResult(statistic=-1.977414824528751, pvalue=0.05912001551822682, df=25.0)
# Midcycle vs Premenstrual paired t-test for COPE9:  TtestResult(statistic=1.498170956042894, pvalue=0.15629469899669923, df=14)

# %%
data = [midcycle9, premenstrual9, interictal9, preictal9, ictal9, postictal9]
significance_tests = [((0, 2), midvsinter9), ((1, 3), premensvspreict9), ((1, 4), premensvsict9), ((1, 5), premensvspostict9), ((0, 1), midvspremens9)]

plot_boxplot_with_significance(data, 'sigclustNoMaskSFG', 'COPE9 (A>N)', significance_tests)

# %%
# one sample t test for each phase with H0 = 0

midcycle_one_sample9 = stats.ttest_1samp(midcycle9, 0)
premenstrual_one_sample9 = stats.ttest_1samp(premenstrual9, 0)
interictal_one_sample9 = stats.ttest_1samp(interictal9, 0)
preictal_one_sample9 = stats.ttest_1samp(preictal9, 0)
ictal_one_sample9 = stats.ttest_1samp(ictal9, 0)
postictal_one_sample9 = stats.ttest_1samp(postictal9, 0)

print(f"Midcycle COPE9 one sample t-test with H0=0: {midcycle_one_sample9}")
print(f"Premenstrual COPE9 one sample t-test with H0=0: {premenstrual_one_sample9}")
print(f"Interictal COPE9 one sample t-test with H0=0: {interictal_one_sample9}")
print(f"Preictal COPE9 one sample t-test with H0=0: {preictal_one_sample9}")
print(f"Ictal COPE9 one sample t-test with H0=0: {ictal_one_sample9}")
print(f"Postictal COPE9 one sample t-test with H0=0: {postictal_one_sample9}")
# Out:
# Midcycle COPE9 one sample t-test with H0=0: TtestResult(statistic=0.3047460890808623, pvalue=0.7650427658182695, df=14)
# Premenstrual COPE9 one sample t-test with H0=0: TtestResult(statistic=-1.76809274726908, pvalue=0.09882136032053745, df=14)
# Interictal COPE9 one sample t-test with H0=0: TtestResult(statistic=1.7453283307678795, pvalue=0.10645563126814794, df=12)
# Preictal COPE9 one sample t-test with H0=0: TtestResult(statistic=1.494199916104461, pvalue=0.16324494169023465, df=11)
# Ictal COPE9 one sample t-test with H0=0: TtestResult(statistic=0.6878731346904178, pvalue=0.5036220290537124, df=13)
# Postictal COPE9 one sample t-test with H0=0: TtestResult(statistic=1.0639821718500646, pvalue=0.31013579310584233, df=11)

# %%
midcycle_thr9 = extract_values(dataframes_mid, (4, 5))
premenstrual_thr9 = extract_values(dataframes_premens, (4, 5))
interictal_thr9 = extract_values(dataframes_int, (4, 5))
preictal_thr9 = extract_values(dataframes_preictal, (4, 5))
ictal_thr9 = extract_values(dataframes_ictal, (4, 5))
postictal_thr9 = extract_values(dataframes_postictal, (4, 5))

# %%
data = [midcycle_thr9, premenstrual_thr9, interictal_thr9, preictal_thr9, ictal_thr9, postictal_thr9]

plot_boxplot(data, 'sigclustNoMaskSFG', 'COPE9 (A>N)')

# %% [markdown]
# COPE10

# %%
midcycle10 = extract_values(dataframes_mid, (2, 5))
premenstrual10 = extract_values(dataframes_premens, (2, 5))
interictal10 = extract_values(dataframes_int, (2, 5))
preictal10 = extract_values(dataframes_preictal, (2, 5))
ictal10 = extract_values(dataframes_ictal, (2, 5))
postictal10 = extract_values(dataframes_postictal, (2, 5))

# %%
# qq plot of each phase

fig, axs = plt.subplots(2, 3, figsize=(8, 4))
fig.suptitle("QQ plots of sigclustNoMaskSFG % mean signal change for each phase in COPE 10")

stats.probplot(midcycle10, dist="norm", plot=axs[0, 0])
axs[0, 0].set_title("Midcycle", fontsize=8)
stats.probplot(premenstrual10, dist="norm", plot=axs[0, 1])
axs[0, 1].set_title("Premenstrual", fontsize=8)
stats.probplot(interictal10, dist="norm", plot=axs[0, 2])
axs[0, 2].set_title("Interictal", fontsize=8)
stats.probplot(preictal10, dist="norm", plot=axs[1, 0])
axs[1, 0].set_title("Preictal", fontsize=8)
stats.probplot(ictal10, dist="norm", plot=axs[1, 1])
axs[1, 1].set_title("Ictal", fontsize=8)
stats.probplot(postictal10, dist="norm", plot=axs[1, 2])
axs[1, 2].set_title("Postictal", fontsize=8)

plt.tight_layout()
plt.show()

# %%
# shaipro-wilk test for normality

midcycle_shapiro10 = stats.shapiro(midcycle10)
premenstrual_shapiro10 = stats.shapiro(premenstrual10)
interictal_shapiro10 = stats.shapiro(interictal10)
preictal_shapiro10 = stats.shapiro(preictal10)
ictal_shapiro10 = stats.shapiro(ictal10)
postictal_shapiro10 = stats.shapiro(postictal10)

print(f"Midcycle: {midcycle_shapiro10}")
print(f"Premenstrual: {premenstrual_shapiro10}")
print(f"Interictal: {interictal_shapiro10}")
print(f"Preictal: {preictal_shapiro10}")
print(f"Ictal: {ictal_shapiro10}")
print(f"Postictal: {postictal_shapiro10}")
# Out:
# Midcycle: ShapiroResult(statistic=0.9167956534594207, pvalue=0.17209912280424827)
# Premenstrual: ShapiroResult(statistic=0.9782947846890221, pvalue=0.9565255393601916)
# Interictal: ShapiroResult(statistic=0.8803089063130736, pvalue=0.0720003677858308)
# Preictal: ShapiroResult(statistic=0.9476749142199089, pvalue=0.6032807421416964)
# Ictal: ShapiroResult(statistic=0.9140033535746609, pvalue=0.18013530331951677)
# Postictal: ShapiroResult(statistic=0.9427601807273006, pvalue=0.5346359086195753)

# %%
# test for significance

midvsinter10 = stats.ttest_ind(midcycle10, interictal10)
premensvspreict10 = stats.ttest_ind(premenstrual10, preictal10)
premensvsict10 = stats.ttest_ind(premenstrual10, ictal10)
premensvspostict10 = stats.ttest_ind(premenstrual10, postictal10)
midvspremens10 = stats.ttest_rel(midcycle10, premenstrual10)

print("Midcycle vs Interictal unpaired t-test for COPE10: ",midvsinter10)
print("Premenstrual vs Preictal unpaired t-test for COPE10: ",premensvspreict10)
print("Premenstrual vs Ictal unpaired t-test for COPE10: ",premensvsict10)
print("Premenstrual vs Postictal unpaired t-test for COPE10: ",premensvspostict10)
print("Midcycle vs Premenstrual paired t-test for COPE10: ",midvspremens10)
# Out:
# Midcycle vs Interictal unpaired t-test for COPE10:  TtestResult(statistic=-1.2450637120461314, pvalue=0.22421372028440983, df=26.0)
# Premenstrual vs Preictal unpaired t-test for COPE10:  TtestResult(statistic=-4.654138022658313, pvalue=9.132289059514757e-05, df=25.0)
# Premenstrual vs Ictal unpaired t-test for COPE10:  TtestResult(statistic=-2.847430035418783, pvalue=0.008322679034807882, df=27.0)
# Premenstrual vs Postictal unpaired t-test for COPE10:  TtestResult(statistic=-1.808156923485821, pvalue=0.08262815956486264, df=25.0)
# Midcycle vs Premenstrual paired t-test for COPE10:  TtestResult(statistic=2.255662797073601, pvalue=0.0406177288423862, df=14)

# %%
data = [midcycle10, premenstrual10, interictal10, preictal10, ictal10, postictal10]
significance_tests = [((0, 2), midvsinter10), ((1, 3), premensvspreict10), ((1, 4), premensvsict10), ((1, 5), premensvspostict10), ((0, 1), midvspremens10)]

plot_boxplot_with_significance(data, 'sigclustNoMaskSFG', 'COPE10 (HA>N)', significance_tests)

# %%
# one sample t test for each phase with H0 = 0

midcycle_one_sample10 = stats.ttest_1samp(midcycle10, 0)
premenstrual_one_sample10 = stats.ttest_1samp(premenstrual10, 0)
interictal_one_sample10 = stats.ttest_1samp(interictal10, 0)
preictal_one_sample10 = stats.ttest_1samp(preictal10, 0)
ictal_one_sample10 = stats.ttest_1samp(ictal10, 0)
postictal_one_sample10 = stats.ttest_1samp(postictal10, 0)

print(f"Midcycle COPE10 one sample t-test with H0=0: {midcycle_one_sample10}")
print(f"Premenstrual COPE10 one sample t-test with H0=0: {premenstrual_one_sample10}")
print(f"Interictal COPE10 one sample t-test with H0=0: {interictal_one_sample10}")
print(f"Preictal COPE10 one sample t-test with H0=0: {preictal_one_sample10}")  
print(f"Ictal COPE10 one sample t-test with H0=0: {ictal_one_sample10}")
print(f"Postictal COPE10 one sample t-test with H0=0: {postictal_one_sample10}")
# Out:
# Midcycle COPE10 one sample t-test with H0=0: TtestResult(statistic=0.14103422394101825, pvalue=0.8898521197290252, df=14)
# Premenstrual COPE10 one sample t-test with H0=0: TtestResult(statistic=-3.6896963396054554, pvalue=0.002426322558612668, df=14)
# Interictal COPE10 one sample t-test with H0=0: TtestResult(statistic=1.619927652191729, pvalue=0.1312122890088682, df=12)
# Preictal COPE10 one sample t-test with H0=0: TtestResult(statistic=3.023664233669501, pvalue=0.0115796520879586, df=11)
# Ictal COPE10 one sample t-test with H0=0: TtestResult(statistic=0.9753428286573046, pvalue=0.3471911268196688, df=13)
# Postictal COPE10 one sample t-test with H0=0: TtestResult(statistic=-0.23820928307924744, pvalue=0.8160979631050235, df=11)

# %%
midcycle_thr10 = extract_values(dataframes_mid, (5, 5))
premenstrual_thr10 = extract_values(dataframes_premens, (5, 5))
interictal_thr10 = extract_values(dataframes_int, (5, 5))
preictal_thr10 = extract_values(dataframes_preictal, (5, 5))
ictal_thr10 = extract_values(dataframes_ictal, (5, 5))
postictal_thr10 = extract_values(dataframes_postictal, (5, 5))

# %%
data = [midcycle_thr10, premenstrual_thr10, interictal_thr10, preictal_thr10, ictal_thr10, postictal_thr10]

plot_boxplot(data, 'sigclustNoMaskSFG', 'COPE10 (HA>N)')
