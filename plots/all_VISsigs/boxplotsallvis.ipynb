# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from scipy import stats
import os
import seaborn as sns

# %%
# import OIL controls 

numbers_controls = range(19, 52)

# Dictionary to store DataFrames
dataframes_midOIL = {}

for i in numbers_controls:
    sub_control = f"sub-control{i:03d}"
    filename = f"featqueryreport_{sub_control}_ses-midcycle_OIL.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOIL_reports", filename)
    if os.path.exists(filepath):
        dataframes_midOIL[f"control{i}_ses-midcycle"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_mid[f'control{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_midOIL))


# Dictionary to store DataFrames
dataframes_premensOIL = {}

for i in numbers_controls:
    sub_control = f"sub-control{i:03d}"
    filename = f"featqueryreport_{sub_control}_ses-premenstrual_OIL.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOIL_reports", filename)
    if os.path.exists(filepath):
        dataframes_premensOIL[f"control{i}_ses-premenstrual"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_premens[f'control{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_premensOIL))

# OIR

# Dictionary to store DataFrames
dataframes_midOIR = {}

for i in numbers_controls:
    sub_control = f"sub-control{i:03d}"
    filename = f"featqueryreport_{sub_control}_ses-midcycle_OIR.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOIR_reports", filename)
    if os.path.exists(filepath):
        dataframes_midOIR[f"control{i}_ses-midcycle"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_mid[f'control{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_midOIR))


# Dictionary to store DataFrames
dataframes_premensOIR = {}

for i in numbers_controls:
    sub_control = f"sub-control{i:03d}"
    filename = f"featqueryreport_{sub_control}_ses-premenstrual_OIR.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOIR_reports", filename)
    if os.path.exists(filepath):
        dataframes_premensOIR[f"control{i}_ses-premenstrual"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_premens[f'control{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_premensOIR))

# oml 

# Dictionary to store DataFrames
dataframes_midOML = {}

for i in numbers_controls:
    sub_control = f"sub-control{i:03d}"
    filename = f"featqueryreport_{sub_control}_ses-midcycle_OML.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOML_reports", filename)
    if os.path.exists(filepath):
        dataframes_midOML[f"control{i}_ses-midcycle"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_mid[f'control{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_midOML))


# Dictionary to store DataFrames
dataframes_premensOML = {}

for i in numbers_controls:
    sub_control = f"sub-control{i:03d}"
    filename = f"featqueryreport_{sub_control}_ses-premenstrual_OML.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOML_reports", filename)
    if os.path.exists(filepath):
        dataframes_premensOML[f"control{i}_ses-premenstrual"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_premens[f'control{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_premensOML))

# omr 

# Dictionary to store DataFrames
dataframes_midOMR = {}

for i in numbers_controls:
    sub_control = f"sub-control{i:03d}"
    filename = f"featqueryreport_{sub_control}_ses-midcycle_OMR.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOMR_reports", filename)
    if os.path.exists(filepath):
        dataframes_midOMR[f"control{i}_ses-midcycle"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_mid[f'control{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_midOMR))


# Dictionary to store DataFrames
dataframes_premensOMR = {}

for i in numbers_controls:
    sub_control = f"sub-control{i:03d}"
    filename = f"featqueryreport_{sub_control}_ses-premenstrual_OMR.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOMR_reports", filename)
    if os.path.exists(filepath):
        dataframes_premensOMR[f"control{i}_ses-premenstrual"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_premens[f'control{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_premensOMR))

# fg

# Dictionary to store DataFrames

dataframes_midFG = {}

for i in numbers_controls:
    sub_control = f"sub-control{i:03d}"
    filename = f"featqueryreport_{sub_control}_ses-midcycle_FG.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISFG_reports", filename)
    if os.path.exists(filepath):
        dataframes_midFG[f"control{i}_ses-midcycle"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_mid[f'control{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_midFG))


# Dictionary to store DataFrames

dataframes_premensFG = {}

for i in numbers_controls:
    sub_control = f"sub-control{i:03d}"
    filename = f"featqueryreport_{sub_control}_ses-premenstrual_FG.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISFG_reports", filename)
    if os.path.exists(filepath):
        dataframes_premensFG[f"control{i}_ses-premenstrual"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_premens[f'control{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_premensFG))


# import LG controls

dataframes_midLG = {}

for i in numbers_controls:
    sub_control = f"sub-control{i:03d}"
    filename = f"featqueryreport_{sub_control}_ses-midcycle_LG.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISLG_reports", filename)
    if os.path.exists(filepath):
        dataframes_midLG[f"control{i}_ses-midcycle"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_mid[f'control{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_midLG))

dataframes_premensLG = {}

for i in numbers_controls:
    sub_control = f"sub-control{i:03d}"
    filename = f"featqueryreport_{sub_control}_ses-premenstrual_LG.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISLG_reports", filename)
    if os.path.exists(filepath):
        dataframes_premensLG[f"control{i}_ses-premenstrual"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_premens[f'control{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_premensLG))

# import pcc controls

dataframes_midPCC = {}

for i in numbers_controls:
    sub_control = f"sub-control{i:03d}"
    filename = f"featqueryreport_{sub_control}_ses-midcycle_PCC.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISPCC_reports", filename)
    if os.path.exists(filepath):
        dataframes_midPCC[f"control{i}_ses-midcycle"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_mid[f'control{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_midPCC))

# Dictionary to store DataFrames
dataframes_premensPCC = {}

for i in numbers_controls:
    sub_control = f"sub-control{i:03d}"
    filename = f"featqueryreport_{sub_control}_ses-premenstrual_PCC.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISPCC_reports", filename)
    if os.path.exists(filepath):
        dataframes_premensPCC[f"control{i}_ses-premenstrual"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_premens[f'control{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_premensPCC))
# Out:
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15

# %%
# import OIL patients

numbers_patients = range(1, 53)

dataframes_intOIL = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-interictal_OIL.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOIL_reports", filename)
    if os.path.exists(filepath):
        dataframes_intOIL[f"patient{i}_ses-interictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_int[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_intOIL))

# Dictionary to store DataFrames
dataframes_preictalOIL = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-preictal_OIL.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOIL_reports", filename)
    if os.path.exists(filepath):
        dataframes_preictalOIL[f"patient{i}_ses-preictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_preictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_preictalOIL))

# Dictionary to store DataFrames
dataframes_ictalOIL = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-ictal_OIL.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOIL_reports", filename)
    if os.path.exists(filepath):
        dataframes_ictalOIL[f"patient{i}_ses-ictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_ictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_ictalOIL))

# Dictionary to store DataFrames
dataframes_postictalOIL = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-postictal_OIL.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOIL_reports", filename)
    if os.path.exists(filepath):
        dataframes_postictalOIL[f"patient{i}_ses-postictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_postictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_postictalOIL))

# oir

# Dictionary to store DataFrames
dataframes_intOIR = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-interictal_OIR.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOIR_reports", filename)
    if os.path.exists(filepath):
        dataframes_intOIR[f"patient{i}_ses-interictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_int[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_intOIR))

# Dictionary to store DataFrames
dataframes_preictalOIR = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-preictal_OIR.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOIR_reports", filename)
    if os.path.exists(filepath):
        dataframes_preictalOIR[f"patient{i}_ses-preictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_preictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_preictalOIR))

# Dictionary to store DataFrames
dataframes_ictalOIR = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-ictal_OIR.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOIR_reports", filename)
    if os.path.exists(filepath):
        dataframes_ictalOIR[f"patient{i}_ses-ictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_ictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_ictalOIR))

# Dictionary to store DataFrames
dataframes_postictalOIR = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-postictal_OIR.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOIR_reports", filename)
    if os.path.exists(filepath):
        dataframes_postictalOIR[f"patient{i}_ses-postictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_postictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_postictalOIR))

# oml

import os
import pandas as pd

# Dictionary to store DataFrames
dataframes_intOML = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-interictal_OML.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOML_reports", filename)
    if os.path.exists(filepath):
        dataframes_intOML[f"patient{i}_ses-interictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_int[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_intOML))

# Dictionary to store DataFrames
dataframes_preictalOML = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-preictal_OML.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOML_reports", filename)
    if os.path.exists(filepath):
        dataframes_preictalOML[f"patient{i}_ses-preictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_preictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_preictalOML))

# Dictionary to store DataFrames
dataframes_ictalOML = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-ictal_OML.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOML_reports", filename)
    if os.path.exists(filepath):
        dataframes_ictalOML[f"patient{i}_ses-ictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_ictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_ictalOML))

# Dictionary to store DataFrames
dataframes_postictalOML = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-postictal_OML.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOML_reports", filename)
    if os.path.exists(filepath):
        dataframes_postictalOML[f"patient{i}_ses-postictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_postictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_postictalOML))

# omr

# Dictionary to store DataFrames
dataframes_intOMR = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-interictal_OMR.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOMR_reports", filename)
    if os.path.exists(filepath):
        dataframes_intOMR[f"patient{i}_ses-interictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_int[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_intOMR))

# Dictionary to store DataFrames
dataframes_preictalOMR = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-preictal_OMR.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOMR_reports", filename)
    if os.path.exists(filepath):
        dataframes_preictalOMR[f"patient{i}_ses-preictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_preictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_preictalOMR))

# Dictionary to store DataFrames
dataframes_ictalOMR = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-ictal_OMR.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOMR_reports", filename)
    if os.path.exists(filepath):
        dataframes_ictalOMR[f"patient{i}_ses-ictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_ictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_ictalOMR))

# Dictionary to store DataFrames
dataframes_postictalOMR = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-postictal_OMR.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISOMR_reports", filename)
    if os.path.exists(filepath):
        dataframes_postictalOMR[f"patient{i}_ses-postictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_postictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_postictalOMR))

# fg

# Dictionary to store DataFrames

dataframes_intFG = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-interictal_FG.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISFG_reports", filename)
    if os.path.exists(filepath):
        dataframes_intFG[f"patient{i}_ses-interictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_int[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_intFG))

# Dictionary to store DataFrames

dataframes_preictalFG = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-preictal_FG.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISFG_reports", filename)
    if os.path.exists(filepath):
        dataframes_preictalFG[f"patient{i}_ses-preictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_preictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_preictalFG))

# Dictionary to store DataFrames

dataframes_ictalFG = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-ictal_FG.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISFG_reports", filename)
    if os.path.exists(filepath):
        dataframes_ictalFG[f"patient{i}_ses-ictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_ictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_ictalFG))

# Dictionary to store DataFrames    

dataframes_postictalFG = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-postictal_FG.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISFG_reports", filename)
    if os.path.exists(filepath):
        dataframes_postictalFG[f"patient{i}_ses-postictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_postictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_postictalFG))

# lg

dataframes_intLG = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-interictal_LG.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISLG_reports", filename)
    if os.path.exists(filepath):
        dataframes_intLG[f"patient{i}_ses-interictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_int[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_intLG))

# Dictionary to store DataFrames
dataframes_preictalLG = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-preictal_LG.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISLG_reports", filename)
    if os.path.exists(filepath):
        dataframes_preictalLG[f"patient{i}_ses-preictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_preictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_preictalLG))

# Dictionary to store DataFrames
dataframes_ictalLG = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-ictal_LG.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISLG_reports", filename)
    if os.path.exists(filepath):
        dataframes_ictalLG[f"patient{i}_ses-ictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_ictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_ictalLG))

# Dictionary to store DataFrames
dataframes_postictalLG = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-postictal_LG.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISLG_reports", filename)
    if os.path.exists(filepath):
        dataframes_postictalLG[f"patient{i}_ses-postictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_postictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_postictalLG))

# import pcc patients

dataframes_intPCC = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-interictal_PCC.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISPCC_reports", filename)
    if os.path.exists(filepath):
        dataframes_intPCC[f"patient{i}_ses-interictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_int[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_intPCC))

# Dictionary to store DataFrames
dataframes_preictalPCC = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-preictal_PCC.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISPCC_reports", filename)
    if os.path.exists(filepath):
        dataframes_preictalPCC[f"patient{i}_ses-preictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_preictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_preictalPCC))

# Dictionary to store DataFrames
dataframes_ictalPCC = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-ictal_PCC.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISPCC_reports", filename)
    if os.path.exists(filepath):
        dataframes_ictalPCC[f"patient{i}_ses-ictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_ictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_ictalPCC))

# Dictionary to store DataFrames
dataframes_postictalPCC = {}

for i in numbers_patients:
    sub_patient = f"sub-patient{i:03d}"
    filename = f"featqueryreport_{sub_patient}_ses-postictal_PCC.txt"
    filepath = os.path.join("C:\\Users\\beama\\OneDrive\\Documents\\uni\\4 ano\\Tese\\Thesis\\plots\\all_VISPCC_reports", filename)
    if os.path.exists(filepath):
        dataframes_postictalPCC[f"patient{i}_ses-postictal"] = pd.read_csv(filepath, sep=" ", header=None)
        #print(f"Successfully read {filename}. Shape: {dataframes_postictal[f'patient{i}_{phase}'].shape}")
    else:
        #print(f"File {filename} not found. Skipping...")
        pass

print(len(dataframes_postictalPCC))
# Out:
# 13
# 12
# 14
# 13
# 13
# 12
# 14
# 13
# 13
# 12
# 14
# 13
# 13
# 12
# 14
# 13
# 13
# 12
# 14
# 13
# 13
# 12
# 14
# 13
# 13
# 12
# 14
# 13

# %%
def extract_values(dataframes, iloc_position):
    extracted_values = []
    for key in dataframes:
        extracted_values.append(dataframes[key].iloc[iloc_position[0], iloc_position[1]])
    return extracted_values

# extract values for each phase in each roi

midcycleOIL = extract_values(dataframes_midOIL, (0, 5))
premenstrualOIL = extract_values(dataframes_premensOIL, (0, 5))
interictalOIL = extract_values(dataframes_intOIL, (0, 5))
preictalOIL = extract_values(dataframes_preictalOIL, (0, 5))
ictalOIL = extract_values(dataframes_ictalOIL, (0, 5))
postictalOIL = extract_values(dataframes_postictalOIL, (0, 5))

midcycleLG = extract_values(dataframes_midLG, (0, 5))
premenstrualLG = extract_values(dataframes_premensLG, (0, 5))
interictalLG = extract_values(dataframes_intLG, (0, 5))
preictalLG = extract_values(dataframes_preictalLG, (0, 5))
ictalLG = extract_values(dataframes_ictalLG, (0, 5))
postictalLG = extract_values(dataframes_postictalLG, (0, 5))

midcyclePCC = extract_values(dataframes_midPCC, (0, 5))
premenstrualPCC = extract_values(dataframes_premensPCC, (0, 5))
interictalPCC = extract_values(dataframes_intPCC, (0, 5))
preictalPCC = extract_values(dataframes_preictalPCC, (0, 5))
ictalPCC = extract_values(dataframes_ictalPCC, (0, 5))
postictalPCC = extract_values(dataframes_postictalPCC, (0, 5))

midcycleOIR = extract_values(dataframes_midOIR, (0, 5))
premenstrualOIR = extract_values(dataframes_premensOIR, (0, 5))
interictalOIR = extract_values(dataframes_intOIR, (0, 5))
preictalOIR = extract_values(dataframes_preictalOIR, (0, 5))
ictalOIR = extract_values(dataframes_ictalOIR, (0, 5))
postictalOIR = extract_values(dataframes_postictalOIR, (0, 5))

midcycleOML = extract_values(dataframes_midOML, (0, 5))
premenstrualOML = extract_values(dataframes_premensOML, (0, 5))
interictalOML = extract_values(dataframes_intOML, (0, 5))
preictalOML = extract_values(dataframes_preictalOML, (0, 5))
ictalOML = extract_values(dataframes_ictalOML, (0, 5))
postictalOML = extract_values(dataframes_postictalOML, (0, 5))

midcycleOMR = extract_values(dataframes_midOMR, (0, 5))
premenstrualOMR = extract_values(dataframes_premensOMR, (0, 5))
interictalOMR = extract_values(dataframes_intOMR, (0, 5))
preictalOMR = extract_values(dataframes_preictalOMR, (0, 5))
ictalOMR = extract_values(dataframes_ictalOMR, (0, 5))
postictalOMR = extract_values(dataframes_postictalOMR, (0, 5))

midcycleFG = extract_values(dataframes_midFG, (0, 5))
premenstrualFG = extract_values(dataframes_premensFG, (0, 5))
interictalFG = extract_values(dataframes_intFG, (0, 5))
preictalFG = extract_values(dataframes_preictalFG, (0, 5))
ictalFG = extract_values(dataframes_ictalFG, (0, 5))
postictalFG = extract_values(dataframes_postictalFG, (0, 5))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Combine all the data into one dictionary
data = {
    'midcycle': {
        'OIL': midcycleOIL,
        'OIR': midcycleOIR,
        'OML': midcycleOML,
        'OMR': midcycleOMR,
        'LG': midcycleLG
    },
    'premenstrual': {
        'OIL': premenstrualOIL,
        'OIR': premenstrualOIR,
        'OML': premenstrualOML,
        'OMR': premenstrualOMR,
        'LG': premenstrualLG
    },
    'interictal': {
        'OIL': interictalOIL,
        'OIR': interictalOIR,
        'OML': interictalOML,
        'OMR': interictalOMR,
        'LG': interictalLG
    },
    'preictal': {
        'OIL': preictalOIL,
        'OIR': preictalOIR,
        'OML': preictalOML,
        'OMR': preictalOMR,
        'LG': preictalLG
    },
    'ictal': {
        'OIL': ictalOIL,
        'OIR': ictalOIR,
        'OML': ictalOML,
        'OMR': ictalOMR,
        'LG': ictalLG
    },
    'postictal': {
        'OIL': postictalOIL,
        'OIR': postictalOIR,
        'OML': postictalOML,
        'OMR': postictalOMR,
        'LG': postictalLG
    }
}

# Plotting
for condition, roi_data in data.items():
    plt.figure(figsize=(10, 6))
    df = pd.DataFrame(roi_data)
    sns.boxplot(data=df, showfliers=False)
    plt.title(f'Boxplot for {condition} condition')
    plt.xlabel('ROI')
    plt.ylabel('Values')
    plt.show()

# %%
formatdata = pd.DataFrame({
    'Phase': ['Midcycle'] * len(midcycleOIL) + ['Premenstrual'] * len(premenstrualOIL) + ['Interictal'] * len(interictalOIL) + \
             ['Midcycle'] * len(midcycleLG) + ['Premenstrual'] * len(premenstrualLG) + ['Interictal'] * len(interictalLG) + \
             ['Midcycle'] * len(midcyclePCC) + ['Premenstrual'] * len(premenstrualPCC) + ['Interictal'] * len(interictalPCC) + \
             ['Preictal'] * len(preictalOIL) + ['Ictal'] * len(ictalOIL) + ['Postictal'] * len(postictalOIL) + \
             ['Preictal'] * len(preictalLG) + ['Ictal'] * len(ictalLG) + ['Postictal'] * len(postictalLG) + \
             ['Preictal'] * len(preictalPCC) + ['Ictal'] * len(ictalPCC) + ['Postictal'] * len(postictalPCC),
    'ROI': ['OIL'] * len(midcycleOIL) + ['OIL'] * len(premenstrualOIL) + ['OIL'] * len(interictalOIL) + \
           ['LG'] * len(midcycleLG) + ['LG'] * len(premenstrualLG) + ['LG'] * len(interictalLG) + \
           ['PCC'] * len(midcyclePCC) + ['PCC'] * len(premenstrualPCC) + ['PCC'] * len(interictalPCC) + \
           ['OIL'] * len(preictalOIL) + ['OIL'] * len(ictalOIL) + ['OIL'] * len(postictalOIL) + \
           ['LG'] * len(preictalLG) + ['LG'] * len(ictalLG) + ['LG'] * len(postictalLG) + \
           ['PCC'] * len(preictalPCC) + ['PCC'] * len(ictalPCC) + ['PCC'] * len(postictalPCC),
    'Mean % Signal Change': midcycleOIL + premenstrualOIL + interictalOIL +
                            midcycleLG + premenstrualLG + interictalLG +
                            midcyclePCC + premenstrualPCC + interictalPCC +
                            preictalOIL + ictalOIL + postictalOIL +
                            preictalLG + ictalLG + postictalLG +
                            preictalPCC + ictalPCC + postictalPCC
})

print(formatdata.head(10))


newROISformatdata = pd.DataFrame({
    'Phase': (['Midcycle'] * (len(midcycleOIL) + len(midcycleOIR) + len(midcycleOML) + len(midcycleOMR))) +
             (['Premenstrual'] * (len(premenstrualOIL) + len(premenstrualOIR) + len(premenstrualOML) + len(premenstrualOMR))) +
             (['Interictal'] * (len(interictalOIL) + len(interictalOIR) + len(interictalOML) + len(interictalOMR))) +
             (['Preictal'] * (len(preictalOIL) + len(preictalOIR) + len(preictalOML) + len(preictalOMR))) +
             (['Ictal'] * (len(ictalOIL) + len(ictalOIR) + len(ictalOML) + len(ictalOMR))) +
             (['Postictal'] * (len(postictalOIL) + len(postictalOIR) + len(postictalOML) + len(postictalOMR))),
    'ROI': (['OIL'] * len(midcycleOIL) + ['OIR'] * len(midcycleOIR) + ['OML'] * len(midcycleOML) + ['OMR'] * len(midcycleOMR)) +
           (['OIL'] * len(premenstrualOIL) + ['OIR'] * len(premenstrualOIR) + ['OML'] * len(premenstrualOML) + ['OMR'] * len(premenstrualOMR)) +
           (['OIL'] * len(interictalOIL) + ['OIR'] * len(interictalOIR) + ['OML'] * len(interictalOML) + ['OMR'] * len(interictalOMR)) +
           (['OIL'] * len(preictalOIL) + ['OIR'] * len(preictalOIR) + ['OML'] * len(preictalOML) + ['OMR'] * len(preictalOMR)) +
           (['OIL'] * len(ictalOIL) + ['OIR'] * len(ictalOIR) + ['OML'] * len(ictalOML) + ['OMR'] * len(ictalOMR)) +
           (['OIL'] * len(postictalOIL) + ['OIR'] * len(postictalOIR) + ['OML'] * len(postictalOML) + ['OMR'] * len(postictalOMR)),
    'Mean % Signal Change': (midcycleOIL + midcycleOIR + midcycleOML + midcycleOMR) +
                            (premenstrualOIL + premenstrualOIR + premenstrualOML + premenstrualOMR) +
                            (interictalOIL + interictalOIR + interictalOML + interictalOMR) +
                            (preictalOIL + preictalOIR + preictalOML + preictalOMR) +
                            (ictalOIL + ictalOIR + ictalOML + ictalOMR) +
                            (postictalOIL + postictalOIR + postictalOML + postictalOMR)
})
# Out:
#       Phase  ROI  Mean % Signal Change
# 0  Midcycle  OIL                 4.634
# 1  Midcycle  OIL                 2.448
# 2  Midcycle  OIL                 1.439
# 3  Midcycle  OIL                 2.959
# 4  Midcycle  OIL                 3.391
# 5  Midcycle  OIL                 4.353
# 6  Midcycle  OIL                 4.928
# 7  Midcycle  OIL                 3.291
# 8  Midcycle  OIL                 4.330
# 9  Midcycle  OIL                 1.381

# %%
print(newROISformatdata.head(30))
# Out:
#        Phase  ROI  Mean % Signal Change
# 0   Midcycle  OIL                 4.634
# 1   Midcycle  OIL                 2.448
# 2   Midcycle  OIL                 1.439
# 3   Midcycle  OIL                 2.959
# 4   Midcycle  OIL                 3.391
# 5   Midcycle  OIL                 4.353
# 6   Midcycle  OIL                 4.928
# 7   Midcycle  OIL                 3.291
# 8   Midcycle  OIL                 4.330
# 9   Midcycle  OIL                 1.381
# 10  Midcycle  OIL                 3.965
# 11  Midcycle  OIL                 4.379
# 12  Midcycle  OIL                 3.513
# 13  Midcycle  OIL                 5.402
# 14  Midcycle  OIL                 1.161
# 15  Midcycle  OIR                 3.831
# 16  Midcycle  OIR                 4.441
# 17  Midcycle  OIR                 2.030
# 18  Midcycle  OIR                 4.324
# 19  Midcycle  OIR                 5.367
# 20  Midcycle  OIR                 6.937
# 21  Midcycle  OIR                 6.779
# ...

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=newROISformatdata, x='Phase', y='Mean % Signal Change', hue='ROI')

# Add labels and title
plt.xlabel('Phase')
plt.ylabel('Mean % Signal Change')
plt.title('Mean % Signal Change Across Phases and ROIs for COPE4 (N,H,A)')
#plt.ylim(-2,2)

# Show legend
plt.legend(title='ROI')

# Show plot
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=formatdata, x='Phase', y='Mean % Signal Change', hue='ROI')

# Add labels and title
plt.xlabel('Phase')
plt.ylabel('Mean % Signal Change')
plt.title('Mean % Signal Change Across Phases and ROIs for COPE4 (N,H,A)')
#plt.ylim(-2,2)

# Show legend
plt.legend(title='ROI')

# Show plot
plt.show()

# %%
# same but violin
plt.figure(figsize=(12, 8))
sns.violinplot(data=formatdata, x='Phase', y='Mean % Signal Change', hue='ROI')

# Add labels and title
plt.xlabel('Phase')
plt.ylabel('Mean % Signal Change')
plt.title('Mean % Signal Change Across Phases and ROIs for H>N')
#plt.ylim(-2.5,2.5)

# Show legend
plt.legend(title='ROI')

# Show plot
plt.show()
